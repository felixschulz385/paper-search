# %%
import pandas as pd
import json
import xml.etree.ElementTree as ET
from tqdm import tqdm

xml_file_path = '../data/Task2_3_combined/NBER_working_papers.xml'
tree = ET.parse(xml_file_path)
root = tree.getroot()

title = root.find('.//atl').text #find returns first instance of title, abstract
abstract = root.find('.//ab').text
data = []
for rec in root.findall('rec'):
    header = rec.find('header')
    #result_id = rec.get('resultID')
    
    #short_db_name = header.get('shortDbName')
    #long_db_name = header.get('longDbName')
    #ui_term = header.get('uiTerm')

    control_info = header.find('controlInfo')
    pubinfo = control_info.find('pubinfo')
    artinfo = control_info.find('artinfo')
    display_info = header.find('displayInfo')
    
    article_data = {
        'publication_year': pubinfo.find('dt').text if pubinfo.find('dt') is not None else None,
        'jtl': control_info.find('./jinfo/jtl').text if control_info.find('./jinfo/jtl') is not None else None,
        'doi': artinfo.find('ui').text if artinfo.find('ui') is not None else None,
        'title': artinfo.find('./tig/atl').text if artinfo.find('./tig/atl') is not None else None,
        'authors': ', '.join([au.text for au in artinfo.findall('./aug/au')]) if artinfo.findall('./aug/au') else None,
        'abstract': artinfo.find('ab').text if artinfo.find('ab') is not None else None,
        'url': display_info.find('./pLink/url').text if display_info.find('./pLink/url') is not None else None
    }
    
    data.append(article_data)

df = pd.DataFrame(data)
df['GPT-Evaluation'] = -1

# %%
df
# Out:
#      publication_year   jtl   doi  \
# 0            20240101  None  None
# 1            20240101  None  None
# 2            20240101  None  None
# 3            20240101  None  None
# 4            20240101  None  None
# ...               ...   ...   ...
# 2576         20220101  None  None
# 2577         20220101  None  None
# 2578         20220101  None  None
# 2579         20220101  None  None
# 2580         20220101  None  None
#
#                                                   title  \
# 0           A Supply Curve for Forest-Based CO2 Removal
# 1     New Area- and Population-based Geographic Cros...
# 2     Decarbonizing Aviation: Cash-for-Clunkers in t...
# 3     The Multigenerational Impact of Children and C...
# 4     Inequality Within Countries is Falling: Underr...
# ...                                                 ...
# 2576          Global Innovation and Knowledge Diffusion
# 2577           Macroeconomic Research, Present and Past
# 2578  Revealing Corruption: Firm and Worker Level Ev...
# 2579                                 Debt as Safe Asset
# 2580  Using Bid Rotation and Incumbency to Detect Co...
#
#                                                 authors  \
# 0          Franklin, Sergio L., Jr., Pindyck, Robert S.
# 1     Ferrara, Andreas, Testa, Patrick A., Zhou, Liyang
# 2     Brueckner, Jan K., Kahn, Matthew E., Nickelsbu...
# 3     Karademir, Sencer, Laliberte, Jean-William P.,...
# 4     Pinkovskiy, Maxim, Sala-i-Martin, Xavier, Chat...
# ...                                                 ...
# 2576                     Lind, Nelson, Ramondo, Natalia
# 2577  Glandon, Philip J., Kuttner, Kenneth, Mazumder...
# 2578  Colonnelli, Emanuele, Lagaras, Spyridon, Ponti...
# 2579  Brunnermeier, Markus K., Merkel, Sebastian A.,...
# 2580  Kawai, Kei, Nakabayashi, Jun, Ortner, Juan M.,...
#
#                                                abstract  \
# 0     Forestation is viewed as an important means of...
# 1     In applied historical research, geographic uni...
# 2     The durability of the transportation capital s...
# 3     This paper examines the multigenerational impa...
# 4     Household surveys suffer from persistent and g...
# ...                                                 ...
# 2576  We develop a Ricardian model of trade in which...
# 2577  How is macroeconomic research conducted and wh...
# 2578  We study how the disclosure of corrupt practic...
# 2579  The price of a safe asset reflects not only th...
# 2580  Cartels participating in procurement auctions ...
#
#                                                     url  GPT-Evaluation
# 0     https://search.ebscohost.com/login.aspx?direct...              -1
# 1     https://search.ebscohost.com/login.aspx?direct...              -1
# 2     https://search.ebscohost.com/login.aspx?direct...              -1
# 3     https://search.ebscohost.com/login.aspx?direct...              -1
# 4     https://search.ebscohost.com/login.aspx?direct...              -1
# ...                                                 ...             ...
# 2576  https://search.ebscohost.com/login.aspx?direct...              -1
# 2577  https://search.ebscohost.com/login.aspx?direct...              -1
# 2578  https://search.ebscohost.com/login.aspx?direct...              -1
# 2579  https://search.ebscohost.com/login.aspx?direct...              -1
# 2580  https://search.ebscohost.com/login.aspx?direct...              -1
#
# [2581 rows x 8 columns]

# %%
jsonl_path = '../data/Task2_3_combined/NBER_workingpapers_batch-output.jsonl'

with open(jsonl_path, 'r') as outputs:
    for (index, row), output_line in zip(df.iterrows(), outputs):
        json_output_obj = json.loads(output_line)
        
        gpt_eval = json_output_obj.get('response', {}).get('body', {}).get('choices', {})[0].get('message').get('content')
        df.at[index, 'GPT-Evaluation'] = gpt_eval
        df.at[index, 'publication_year'] = df.at[index, 'publication_year'][:4]

df.to_excel('../data/Task2_3_combined/NBER_workingpapers_of_interest.xlsx', index=False)
# Out:
# C:\Users\ramkr\AppData\Local\Temp\ipykernel_23688\3474137303.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, 'GPT-Evaluation'] = gpt_eval

# %%
count_tens = (df["GPT-Evaluation"] == "9").sum()
print("Number of entries equal to '10':", count_tens)
# Out:
# Number of entries equal to '10': 6

# %%
count = (df["GPT-Evaluation"] == "6").sum()
print(count)
# Out:
# 6

# %% [markdown]
# ##### Combine two excel sheets

# %%
import pandas as pd

df1 = pd.read_excel('../data/Task2_3_combined/source_papers_of_interest.xlsx', sheet_name='Sheet1')
df2 = pd.read_excel('../data/Task2_3_combined/NBER_workingpapers_of_interest.xlsx', sheet_name='Sheet1')

output_file = '../data/Task2_3_combined/result.xlsx'

with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
    df1.to_excel(writer, sheet_name='Sheet1', index=False)
    df2.to_excel(writer, sheet_name='Sheet2', index=False)

print("Sheets combined into:", output_file)
# Out:
# Sheets combined into: ../data/Task2_3_combined/result.xlsx
